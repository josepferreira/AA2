# %%
##Definir os tipos dos dados
dtypes = {
        'MachineIdentifier':                                    'category',
        'ProductName':                                          'category',
        'EngineVersion':                                        'category',
        'AppVersion':                                           'category',
        'AvSigVersion':                                         'category',
        'IsBeta':                                               'int8',
        'RtpStateBitfield':                                     'float16',
        'IsSxsPassiveMode':                                     'int8',
        'DefaultBrowsersIdentifier':                            'float32',
        'AVProductStatesIdentifier':                            'float32',
        'AVProductsInstalled':                                  'float16',
        'AVProductsEnabled':                                    'float16',
        'HasTpm':                                               'int8',
        'CountryIdentifier':                                    'int16',
        'CityIdentifier':                                       'float32',
        'OrganizationIdentifier':                               'float16',
        'GeoNameIdentifier':                                    'float16',
        'LocaleEnglishNameIdentifier':                          'int16',
        'Platform':                                             'category',
        'Processor':                                            'category',
        'OsVer':                                                'category',
        'OsBuild':                                              'int16',
        'OsSuite':                                              'int16',
        'OsPlatformSubRelease':                                 'category',
        'OsBuildLab':                                           'category',
        'SkuEdition':                                           'category',
        'IsProtected':                                          'float16',
        'AutoSampleOptIn':                                      'int8',
        'PuaMode':                                              'category',
        'SMode':                                                'float16',
        'IeVerIdentifier':                                      'float16',
        'SmartScreen':                                          'category',
        'Firewall':                                             'float16',
        'UacLuaenable':                                         'float64', # was 'float32'
        'Census_MDC2FormFactor':                                'category',
        'Census_DeviceFamily':                                  'category',
        'Census_OEMNameIdentifier':                             'float32', # was 'float16'
        'Census_OEMModelIdentifier':                            'float32',
        'Census_ProcessorCoreCount':                            'float16',
        'Census_ProcessorManufacturerIdentifier':               'float16',
        'Census_ProcessorModelIdentifier':                      'float32', # was 'float16'
        'Census_ProcessorClass':                                'category',
        'Census_PrimaryDiskTotalCapacity':                      'float64', # was 'float32'
        'Census_PrimaryDiskTypeName':                           'category',
        'Census_SystemVolumeTotalCapacity':                     'float64', # was 'float32'
        'Census_HasOpticalDiskDrive':                           'int8',
        'Census_TotalPhysicalRAM':                              'float32',
        'Census_ChassisTypeName':                               'category',
        'Census_InternalPrimaryDiagonalDisplaySizeInInches':    'float32', # was 'float16'
        'Census_InternalPrimaryDisplayResolutionHorizontal':    'float32', # was 'float16'
        'Census_InternalPrimaryDisplayResolutionVertical':      'float32', # was 'float16'
        'Census_PowerPlatformRoleName':                         'category',
        'Census_InternalBatteryType':                           'category',
        'Census_InternalBatteryNumberOfCharges':                'float64', # was 'float32'
        'Census_OSVersion':                                     'category',
        'Census_OSArchitecture':                                'category',
        'Census_OSBranch':                                      'category',
        'Census_OSBuildNumber':                                 'int16',
        'Census_OSBuildRevision':                               'int32',
        'Census_OSEdition':                                     'category',
        'Census_OSSkuName':                                     'category',
        'Census_OSInstallTypeName':                             'category',
        'Census_OSInstallLanguageIdentifier':                   'float16',
        'Census_OSUILocaleIdentifier':                          'int16',
        'Census_OSWUAutoUpdateOptionsName':                     'category',
        'Census_IsPortableOperatingSystem':                     'int8',
        'Census_GenuineStateName':                              'category',
        'Census_ActivationChannel':                             'category',
        'Census_IsFlightingInternal':                           'float16',
        'Census_IsFlightsDisabled':                             'float16',
        'Census_FlightRing':                                    'category',
        'Census_ThresholdOptIn':                                'float16',
        'Census_FirmwareManufacturerIdentifier':                'float16',
        'Census_FirmwareVersionIdentifier':                     'float32',
        'Census_IsSecureBootEnabled':                           'int8',
        'Census_IsWIMBootEnabled':                              'float16',
        'Census_IsVirtualDevice':                               'float16',
        'Census_IsTouchEnabled':                                'int8',
        'Census_IsPenCapable':                                  'int8',
        'Census_IsAlwaysOnAlwaysConnectedCapable':              'float16',
        'Wdft_IsGamer':                                         'float16',
        'Wdft_RegionIdentifier':                                'float16',
        'HasDetections':                                        'int8'
        }

# %%
import pandas as pd
### Ler dataset
df = pd.read_csv('train_100k.csv',low_memory=False,dtype=dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-19b19fe3dd9c> in <module>
#       2 ### Ler dataset
#       3 df = pd.read_csv('train_100k.csv',low_memory=False,dtype=dtypes)
# ----> 4 df.target_names
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'target_names'

# %%
## Ver se ha nulos
pd.isnull(df).sum()
# Out:
# MachineIdentifier                               0
# ProductName                                     0
# EngineVersion                                   0
# AppVersion                                      0
# AvSigVersion                                    0
# IsBeta                                          0
# RtpStateBitfield                             3666
# IsSxsPassiveMode                                0
# DefaultBrowsersIdentifier                  951696
# AVProductStatesIdentifier                    4093
# AVProductsInstalled                          4093
# AVProductsEnabled                            4093
# HasTpm                                          0
# CountryIdentifier                               0
# CityIdentifier                              36512
# OrganizationIdentifier                     308936
# GeoNameIdentifier                              19
# LocaleEnglishNameIdentifier                     0
# Platform                                        0
# ...

# %%
#df.head()
print(df['CityIdentifier'])
# Out:
# 0        128035.0
# 1          1482.0
# 2        153579.0
# 3         20710.0
# 4         37376.0
# 5         13598.0
# 6         81215.0
# 7        150323.0
# 8        155006.0
# 9         98572.0
# 10       133897.0
# 11       120983.0
# 12         7198.0
# 13       124736.0
# 14       141516.0
# 15       114477.0
# 16         7198.0
# 17        64168.0
# 18       136271.0
# 19        79230.0
# 20            NaN
# 21        12607.0
# 22        77794.0
# 23       110781.0
# 24       143782.0
# 25        37357.0
# 26        11382.0
# 27       110673.0
# 28       150207.0
# 29        20805.0
#            ...
# 99969     98572.0
# 99970     29575.0
# 99971    123157.0
# 99972     22656.0
# 99973    143155.0
# 99974     16668.0
# 99975    137827.0
# 99976     20805.0
# 99977    128076.0
# 99978     82373.0
# 99979     75425.0
# 99980    114674.0
# 99981     58607.0
# 99982    144018.0
# 99983    162971.0
# 99984    122689.0
# 99985     70124.0
# 99986     62396.0
# 99987     21497.0
# ...

# %%
df.shape
df.count()
# Out:
# MachineIdentifier                          999999
# ProductName                                999999
# EngineVersion                              999999
# AppVersion                                 999999
# AvSigVersion                               999999
# IsBeta                                     999999
# RtpStateBitfield                           996333
# IsSxsPassiveMode                           999999
# DefaultBrowsersIdentifier                   48303
# AVProductStatesIdentifier                  995906
# AVProductsInstalled                        995906
# AVProductsEnabled                          995906
# HasTpm                                     999999
# CountryIdentifier                          999999
# CityIdentifier                             963487
# OrganizationIdentifier                     691063
# GeoNameIdentifier                          999980
# LocaleEnglishNameIdentifier                999999
# Platform                                   999999
# ...

# %%
df.min()
# Out:
# MachineIdentifier                               0000028988387b115f69f31a3bf04f09
# ProductName                                                                  fep
# EngineVersion                                                        1.1.10302.0
# AppVersion                                                          4.10.14393.0
# AvSigVersion                                                             0.0.0.0
# IsBeta                                                                         0
# RtpStateBitfield                                                               0
# IsSxsPassiveMode                                                               0
# DefaultBrowsersIdentifier                                                      1
# AVProductStatesIdentifier                                                      6
# AVProductsInstalled                                                            1
# AVProductsEnabled                                                              0
# ...

# %%
#df['ProductName']=pd.to_numeric(df.ProductName)
#print(df['ProductName'])
df.ProductName[df.ProductName == 'win8defender'] = 1
df.ProductName[df.ProductName == 'mse'] = 2
print(df['ProductName'])
# Out:
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        2
# 12        2
# 13        2
# 14        2
# 15        2
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        2
# 22        2
# 23        2
# 24        2
# 25        2
# 26        2
# 27        2
# 28        2
# 29        2
#          ..
# 999969    2
# 999970    2
# 999971    2
# 999972    2
# 999973    2
# 999974    2
# 999975    2
# 999976    2
# 999977    2
# 999978    2
# 999979    2
# 999980    2
# 999981    2
# 999982    2
# 999983    2
# 999984    2
# 999985    2
# 999986    2
# 999987    2
# 999988    2
# 999989    2
# 999990    2
# 999991    2
# 999992    2
# 999993    2
# 999994    2
# 999995    2
# 999996    2
# 999997    2
# 999998    2
# Name: ProductName, Length: 999999, dtype: int64
# /home/pc/.local/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
pname = {'win8defender': 1,'mse': 2} 
  
# traversing through dataframe 
# Gender column and writing 
# values where key matches 
df['ProductName'] = [ProductName[item] for item in df.ProductName] 
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-842f8393c2e9> in <module>
#       4 # Gender column and writing
#       5 # values where key matches
# ----> 6 df['ProductName'] = [ProductName[item] for item in df.ProductName]
#       7 print(data)
#
# <ipython-input-7-842f8393c2e9> in <listcomp>(.0)
#       4 # Gender column and writing
#       5 # values where key matches
# ----> 6 df['ProductName'] = [ProductName[item] for item in df.ProductName]
#       7 print(data)
#
# NameError: name 'ProductName' is not defined
